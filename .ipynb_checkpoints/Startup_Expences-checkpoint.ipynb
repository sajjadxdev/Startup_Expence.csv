# %%
# !pip install pandas numpy
# Out:
# Requirement already satisfied: pandas in c:\users\user\appdata\roaming\python\python313\site-packages (2.2.3)
# Requirement already satisfied: numpy in c:\users\user\appdata\roaming\python\python313\site-packages (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\appdata\roaming\python\python313\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\appdata\roaming\python\python313\site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Startups_Expense.csv')

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
df1=pd.get_dummies(df['State'],drop_first=True)

# %%
df=pd.concat([df1,df],axis=1)

# %%
df.drop('State',axis=1,inplace=True)

# %%
df.head()
# Out:
#    Florida  New York  R&D Spend  Administration  Marketing Spend     Profit
# 0    False      True  165349.20       136897.80        471784.10  192261.83
# 1    False     False  162597.70       151377.59        443898.53  191792.06
# 2     True     False  153441.51       101145.55        407934.54  191050.39
# 3    False      True  144372.41       118671.85        383199.62  182901.99
# 4     True     False  142107.34        91391.77        366168.42  166187.94

# %%
df[['Florida','New York']]=df[['Florida','New York']].astype(int)

# %%
df.head()
# Out:
#    Florida  New York  R&D Spend  Administration  Marketing Spend     Profit
# 0        0         1  165349.20       136897.80        471784.10  192261.83
# 1        0         0  162597.70       151377.59        443898.53  191792.06
# 2        1         0  153441.51       101145.55        407934.54  191050.39
# 3        0         1  144372.41       118671.85        383199.62  182901.99
# 4        1         0  142107.34        91391.77        366168.42  166187.94

# %%
X=df.iloc[:,:-1]
y=df.iloc[:,[5]]

# %%
X.head(2)
# Out:
#    Florida  New York  R&D Spend  Administration  Marketing Spend
# 0        0         1   165349.2       136897.80        471784.10
# 1        0         0   162597.7       151377.59        443898.53

# %%
y.head(2)
# Out:
#       Profit
# 0  192261.83
# 1  191792.06

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
from sklearn.linear_model import  LinearRegression

# %%
regression=LinearRegression()

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regression.predict(X_test)

# %%
from sklearn.metrics import r2_score  
from sklearn.metrics import confusion_matrix

# %%
score=r2_score(y_test,y_pred)

# %%
score
# Out:
# 0.9624770353520667
